# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
import cv2

# %%
dark = cv2.imread("dark.jpg")
plt.figure(figsize=(14,5))
plt.subplot(121)
sns.histplot(dark.ravel())
plt.subplot(122)
plt.imshow(dark)

# %%
BRIGHT = cv2.imread("BRIGHT.jpg")
plt.figure(figsize=(14,5))
plt.subplot(121)
sns.histplot(BRIGHT.ravel())
plt.subplot(122)
plt.imshow(BRIGHT)

# %%
HIGH_CONSTRACT = cv2.imread("HIGH_CONSTRACT.jpg")
plt.figure(figsize=(14,5))
plt.subplot(121)
sns.histplot(HIGH_CONSTRACT.ravel())
plt.subplot(122)
plt.imshow(HIGH_CONSTRACT)

# %%
LOW_CONSTARCT = cv2.imread("LOW_CONSTARCT.jpg")
plt.figure(figsize=(14,5))
plt.subplot(121)
sns.histplot(LOW_CONSTARCT.ravel())
plt.subplot(122)
plt.imshow(LOW_CONSTARCT)
